# %%
# version numpy required to be < 2 (for example 1.26.3 is ok for qwen)

# %%
# !ACCELERATE_LOG_LEVEL=info accelerate launch \
--config_file zero3.yaml \
--num_processes=3 \
train_grpo.py \
# Out:
# [2025-02-09 17:07:32,343] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# INFO:root:Using nproc_per_node=3.
# W0209 17:07:33.427000 281 site-packages/torch/distributed/run.py:793]
# W0209 17:07:33.427000 281 site-packages/torch/distributed/run.py:793] *****************************************
# W0209 17:07:33.427000 281 site-packages/torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0209 17:07:33.427000 281 site-packages/torch/distributed/run.py:793] *****************************************
# [2025-02-09 17:07:36,719] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2025-02-09 17:07:36,839] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# ...
